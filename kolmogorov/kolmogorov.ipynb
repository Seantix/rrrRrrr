# %% [markdown]
# Берем данные с лабораторной "моделирование случайной величины", измеряли разброс значений частоты ЭМ колебаний.

# %%
import pandas


freqs = pandas.read_csv("freqs.csv")
freqs['freqs'].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Проверили анализ выборки - сходится с тем, что мы делали вручную. Появилось ощущение потерянных сил и нервов :(

# %%
print(freqs.freqs.describe())
# Out:
# count    50.000000
# mean      1.736726
# std       0.050548
# min       1.633000
# 25%       1.700650
# 50%       1.728800
# 75%       1.765725
# max       1.862400
# Name: freqs, dtype: float64

# %%
freqs.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# Проверим наконец то на нормальность ( я то знаю что она вполне вполне нормальная) )

# %%
from scipy.stats import kstest
f = freqs['freqs']

print(kstest(f , 'norm', (freqs.mean(), freqs.std())))
# Out:
# KstestResult(statistic=0.0807399388878719, pvalue=0.8741890015079095)

# %% [markdown]
# Что и требовалось доказать :)
#
# К-С-статистика мала, Р-значение велико. Ура, выборка нормальная!!
